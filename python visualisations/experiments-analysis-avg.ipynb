# %% [markdown]
# BehaviorSpace results (NetLogo 6.4.0)	Table version 2.0
# social-media-polarisation.nlogo
# Experiment 1.0
# 11/20/2024 18:06:08:141 +0000
# min-pxcor	max-pxcor	min-pycor	max-pycor
# -50	50	-50	50

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np

# %%
data = pd.read_csv('experiments/baseline-experiment.csv')
data = data.sort_values('[step]')
data.head(5)
# Out:
#    [run number]  avg-num-groups-per-agent  sd-num-groups-per-agent  \
# 0             2                         2                        1
# 1             5                         2                        1
# 2             3                         2                        1
# 3             1                         2                        1
# 4             4                         2                        1
#
#    group-strength-increase  gamma0  gamma1  num-agents  base-death-rate  \
# 0                     0.05     1.5    -0.5         350           0.0002
# 1                     0.05     1.5    -0.5         350           0.0002
# 2                     0.05     1.5    -0.5         350           0.0002
# 3                     0.05     1.5    -0.5         350           0.0002
# 4                     0.05     1.5    -0.5         350           0.0002
#
#    bubble-size  max-ticks  ...  opinion-extremity-increase  alpha2  max-age  \
# 0           25       5000  ...                        0.01     0.3      100
# 1           25       5000  ...                        0.01     0.3      100
# 2           25       5000  ...                        0.01     0.3      100
# 3           25       5000  ...                        0.01     0.3      100
# 4           25       5000  ...                        0.01     0.3      100
#
#    multiple-group-membership?  offline-interaction-interval  birth-rate  \
# 0                        True                            50    0.157396
# 1                        True                            50    0.157396
# 2                        True                            50    0.157396
# 3                        True                            50    0.157396
# 4                        True                            50    0.157396
#
#    interaction-radius  age-death-factor  [step]  \
# 0                   1              0.02       0
# 1                   1              0.02       0
# 2                   1              0.02       0
# 3                   1              0.02       0
# 4                   1              0.02       0
#
#                                 [opinion] of turtles
# 0  [0.21804404304454839 0.5421866183648183 0.7862...
# 1  [0.861168859132074 0.04428065207132015 0.90508...
# 2  [0.43159092177700586 0.228496071036425 0.10820...
# 3  [0.6231372992921014 0.6190663737046632 0.97008...
# 4  [0.9906742741030505 0.24131452578852397 0.6154...
#
# [5 rows x 28 columns]

# %%
df = pd.DataFrame(data[['[opinion] of turtles', '[run number]']])
df.rename(columns={'[opinion] of turtles': 'opinions', '[run number]': 'run'}, inplace=True)
df['opinions'] = df['opinions'].apply(lambda x: re.findall(r"[-+]?\d*\.\d+|\d+", x))
df['opinions'] = df['opinions'].apply(lambda x: [float(i) for i in x])
df['avg'] = df['opinions'].apply(lambda x: np.median(x))
df['run_index'] = df.groupby('run').cumcount()
# df = df.iloc[::100, :]
df.head(5)
# Out:
#                                             opinions  run       avg  run_index
# 0  [0.21804404304454839, 0.5421866183648183, 0.78...    2  0.508860          0
# 1  [0.861168859132074, 0.04428065207132015, 0.905...    5  0.534333          0
# 2  [0.43159092177700586, 0.228496071036425, 0.108...    3  0.471191          0
# 3  [0.6231372992921014, 0.6190663737046632, 0.970...    1  0.478467          0
# 4  [0.9906742741030505, 0.24131452578852397, 0.61...    4  0.450434          0

# %%
# df_exploded = df.explode('opinions')
# df_exploded.head(5)

# %%
# plt.figure(figsize=(10, 6))
# sns.lineplot(data=df_exploded, x='iteration', y='opinions')
# plt.title('Opinions of Turtles Over Iterations')
# plt.xlabel('Iteration')
# plt.ylabel('Opinions')
# plt.savefig('baseline-experiment.png', dpi=300)
# plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='run_index', y='avg', hue='run', palette='tab20', errorbar=None)
plt.title('Opinions of Turtles Over Iterations (All Runs)')
plt.xlabel('Iteration')
plt.ylabel('Opinions')
plt.legend(title='Run Number')
plt.savefig('plots/baseline-experiment-runs-median-all.png', dpi=300)
plt.show()
